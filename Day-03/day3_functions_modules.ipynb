# %% [markdown]
# # Day 3: Python Foundations — Functions and Modular Programming
#
# Welcome to **Day 3 of the Industrial Training for AI & Machine Learning**!
#
# Yesterday, we learned about loops, operators, and control flow to direct program execution. Today, we will study **Functions**—the building blocks of reusable and modular code. In AI/ML, functions are used everywhere: from defining custom data preprocessing pipelines, wrapping evaluation metrics, designing neural network layers, to structuring experiment run loggers.
#
# ---
#
# ## Learning Objectives
# By the end of this session, you will understand:
# 1. **Built-in Functions**: Explore and apply standard Python helper functions (`len`, `sum`, `max`, `min`, `abs`, `round`).
# 2. **Custom Functions**: How to define and call your own functions using the `def` keyword.
# 3. **Parameters vs. Arguments**: Passing information into functions.
# 4. **The `return` Statement**: Getting results back from functions to use in other calculations.
# 5. **Types of Arguments**: Positional, keyword, default parameters, and variable-length arguments (`*args`, `**kwargs`).
# 6. **Variable Scope**: Understanding local vs. global variables and the `global` keyword.
# 7. **Recursive Functions**: Functions that call themselves (e.g., Factorial, Fibonacci).

# %% [markdown]
# ## 1. Built-in (Inbuilt) Functions in Python
#
# Python has several functions that are already created and ready to use. These are called **built-in functions**. In AI/ML, we use them constantly to get basic statistics of our dataset, inspect list lengths, or round float metrics.
#
# Commonly used built-in functions:
# - `len(sequence)`: Returns the number of items in a list, tuple, set, string, etc.
# - `sum(iterable)`: Adds up all elements of a numerical collection.
# - `max(iterable)` / `min(iterable)`: Returns the largest or smallest element.
# - `abs(number)`: Returns the absolute (positive) value of a number (important for calculating absolute errors).
# - `round(number, digits)`: Rounds a floating-point number to a specified number of decimal places.
# - `print(...)`: Outputs text or values to the screen.

# %%
list1=[10,20,30,40,50]
str1="wbwhdbwbdwh"
print(len(list1))
print(min(list1))
# Out:
# 5
# 10

# %%
abc=345
print("variable is :",abc,"hey")
print(f"variable is : {abc}")
# Out:
# variable is : 345
# variable is : 345

# %%
num=34.3625463
print(round(num,3))
# Out:
# 34.363

# %%
num=-5
print(abs(num))
list1=[10,-20,30,-262]
for a in list1:
    print(abs(a))
# Out:
# 5
# 10
# 20
# 30
# 262

# %%
password="abc@123"
list1=[10,20,30,262]
print(len(password))
print(len(list1))
print(sum(list1))
print(min(list1))
# Out:
# 7
# 4
# 322
# 10

# %%
abc=4.587863
print(round(abc,2))

print("hey")
print(f"heyy {abc}")
print("heyy {abc}",abc,"done",abc)
# Out:
# 4.59
# hey
# heyy 4.587863
# heyy {abc} 4.587863 done

# %%
# Practical Examples of Built-in Functions in AI/ML
dataset_losses = [0.85, -0.42, 0.15, -0.98, 0.05]
for a in dataset_losses:
    print(abs(a))
# 1. Find the size of our dataset
num_samples = len(dataset_losses)
print(f"Number of training samples: {num_samples}")

# 2. Find the maximum and minimum loss
max_loss = max(dataset_losses)
min_loss = min(dataset_losses)
print(f"Max Loss: {max_loss} | Min Loss: {min_loss}")

# 3. Sum all losses to find the average loss
total_loss = sum(dataset_losses)
average_loss = total_loss / num_samples
print(f"Average Loss: {round(average_loss, 4)}")

# 4. Absolute error (difference between prediction and actual)
prediction_error = -0.27
absolute_error = abs(prediction_error)
print(f"Error: {prediction_error} | Absolute Error: {absolute_error}")
# Out:
# 0.85
# 0.42
# 0.15
# 0.98
# 0.05
# Number of training samples: 5
# Max Loss: 0.85 | Min Loss: -0.98
# Average Loss: -0.07
# Error: -0.27 | Absolute Error: 0.27

# %% [markdown]
# ## 2. Creating Custom Functions
#
# While built-in functions are great, most of the time we need to write custom logic. In Python, we define a function using the **`def`** keyword, followed by the function name, parentheses `()`, and a colon `:`. The code inside the function must be indented.
#
# ### 2.1 Defining and Calling a Simple Function
# A function does not run when you define it; it only runs when you explicitly **call** (execute) it by writing its name followed by parentheses.

# %%
# Defining a simple function
def welcome_student():
    print("Welcome to AI/ML Industrial Training!")
    print("Let's build some functions today!")
# Calling the function
welcome_student()
# Out:
# Welcome to AI/ML Industrial Training!
# Let's build some functions today!

# %% [markdown]
# ### 2.2 Parameters and Arguments
# Functions are much more useful when we can pass data into them. We do this by defining **parameters** (variable placeholders) inside the parentheses. When calling the function, we pass the actual values (**arguments**) into it.
# - **Parameter**: The variable listed in the function definition (e.g., `username`).
# - **Argument**: The actual value sent to the function when it is called (e.g., `"Amit"`).

# %%
# Function with a parameter
def greet_user(username,course):
    print(f"Hello, {username}! Ready to train some models today?, {course}")

# Calling the function with different arguments
greet_user("Amit","Btech")
greet_user("Priya","BCA")
# Out:
# Hello, Amit! Ready to train some models today?, Btech
# Hello, Priya! Ready to train some models today?, BCA

# %%
def calculate(a,b,symbol):
    if symbol=="+":
        print(a+b)
    elif symbol=="-":
        print(a-b)
    elif symbol=="*":
        print(a*b)
    elif symbol=="/":
        print(a/b)

calculate(20,30,"+")
# Out:
# 50

# %%
def table(num):
    for i in range(0,11):
        print(f"{num} * {i} = {num*i}")

table(5)
# Out:
# 5 * 0 = 0
# 5 * 1 = 5
# 5 * 2 = 10
# 5 * 3 = 15
# 5 * 4 = 20
# 5 * 5 = 25
# 5 * 6 = 30
# 5 * 7 = 35
# 5 * 8 = 40
# 5 * 9 = 45
# 5 * 10 = 50

# %% [markdown]
# ### Exercise 1: Create your own `add` function!
# Write a function named `add_numbers` that:
# 1. Takes two parameters: `num1` and `num2`.
# 2. Inside the function, calculates the sum and prints: `"Sum inside function: [value]"`.
# 3. Call the function with arguments `15` and `25`.
#
# *(Write your code in the cell below)*

# %%
# Exercise 1: Write your code here
def add(a,b):
    res=a+b
    print(res)

add(10,30)
# Out:
# 40

# %% [markdown]
# ## 3. The `return` Statement
#
# In the previous exercise, your function printed the sum on the screen. However, printing is only for humans to see. In a program, we usually need the function to **return** the calculated value back so we can save it in a variable and use it in other calculations.
#
# We use the **`return`** keyword to send a value back to the caller.
#
# > [gradient-alert]
# > A function exits immediately when it hits a `return` statement. Any lines of code written after `return` inside the same function scope are **unreachable** and will not execute.

# %%
# Function returning a value
def calculate_square(number):
    square_value = number * number
    return square_value
    print("This print statement is unreachable and will never run!")
    
calculate_square(5)
result = calculate_square(5)
print(f"Returned Result: {result}")

# Using the returned result in another calculation
adjusted_score = result + 10
print(f"Adjusted Score (result + 10): {adjusted_score}")
# Out:
# Returned Result: 25
# Adjusted Score (result + 10): 35

# %% [markdown]
# ## Exercise 2: Checking for Prime Numbers
# Write a function named is_prime(n) that:
# 1. Takes an integer n as an input.
# 2. Returns True if the number is prime, and False otherwise.
# 3. Call the function with the value 11, store the returned value in a variable named result, and print: "Is 11 prime?: [result]".
#
# (Write your code in the cell below)

# %%
def is_prime(n):
    for i in range(2,int(n**0.5)+1):
        if n%i==0:
            print("not prime")
            break
    else:
        print("prime")

is_prime(a)
a=int(input("enter number"))
# Out:
# not prime

# %%
def is_prime(n):
    for i in range(2,int(n**0.5)+1):
        if n%i==0:
            print("not prime")
            break
    else:
        print("prime")
a=int(input("enter any number"))
is_prime(a)
# Out:
# not prime

# %%
# Exercise 2: Write your code here
def is_prime(n):
    if n <= 1:
        return False
    for i in range(2, int(n**0.5) + 1):
        if n % i == 0:
            return False  
    return True  
print(is_prime(11))
# Call the function with the value 11
result = is_prime(11)

# Print the final result
print(f"Is 11 prime?: {result}")
# Out:
# True
# Is 11 prime?: True

# %% [markdown]
# ## 4. Types of Arguments
#
# Python is highly flexible in how parameters are passed to functions. Let's look at the primary ways:
#
# ### 4.1 Positional vs. Keyword Arguments
# - **Positional Arguments**: Assigned based on the order they are passed.
# - **Keyword Arguments**: Passed with name-value pairs (e.g., `parameter=value`), allowing you to pass them in any order.
#
# ### 4.2 Default Arguments
# You can assign a default value to a parameter in the function definition. If the caller does not pass an argument for that parameter, the default is used.

# %%
# Function showing argument styles
def intro(name, age=18, course='12th'):
    print(f"'{name}' is {age} years old , study in {course} class")

# 1. Positional arguments only (order matches parameters)
intro("sahil", 17, "11th")

# 2. Using the default arguments (only passing model_name)
intro("priya")

# 3. Keyword arguments (order doesn't matter, defaults can be modified)
intro(course="9th", name="sakshi", age=15)
# Out:
# 'sahil' is 17 years old , study in 11th class
# 'sahil' is 11th years old , study in 17 class
# 'priya' is 18 years old , study in 12th class
# 'sakshi' is 15 years old , study in 9th class

# %% [markdown]
# ### 4.3 Variable-Length Arguments (`*args` and `**kwargs`)
# Sometimes, you don't know how many arguments will be passed to your function. Python provides two special symbols:
# - **`*args`**: Collects extra positional arguments into a **Tuple**.
# - **`**kwargs`**: Collects extra keyword arguments into a **Dictionary**.
#
# *(This is common in ML libraries like Scikit-Learn or PyTorch when passing variable configurations to sub-modules!)*

# %%
dict1={"Name":"swastik","class":"Btech"}
print(dict1)
print(dict1.items())
for key,value in dict1.items():
    print(key,value)
# Out:
# {'Name': 'swastik', 'class': 'Btech'}
# dict_items([('Name', 'swastik'), ('class', 'Btech')])
# Name swastik
# class Btech

# %%
# Example of *args
def calculate_total_expenses(*expenses):
    print(f"Expenses received: {expenses} (Type: {type(expenses)})")
    return sum(expenses)

total = calculate_total_expenses(12.5, 45.0, 100.25, 7.8)
print(total)

# Example of **kwargs
def print_model_parameters(**hyperparams):
    print(f"Hyperparameters received:{hyperparams}(Type:{type(hyperparams)})")
    for key, value in hyperparams.items():
        print(f"  - {key}: {value}")

print_model_parameters(learning_rate=0.001, batch_size=64, dropout=0.3)
# Out:
# Expenses received: 100.25 (Type: <class 'tuple'>)
# 165.55
# Hyperparameters received:{'learning_rate': 0.001, 'batch_size': 64, 'dropout': 0.3}(Type:<class 'dict'>)
#   - learning_rate: 0.001
#   - batch_size: 64
#   - dropout: 0.3

# %% [markdown]
# ## 5. Variable Scope: Local vs. Global
#
# Variables are not accessible everywhere in a Python script. Where a variable is defined determines its **scope**:
# - **Global Scope**: Variables defined outside any function. They can be read anywhere in the file.
# - **Local Scope**: Variables defined inside a function. They can only be accessed *inside* that function. Once the function finishes running, local variables are destroyed.

# %%
# Global variable
metric_name = "Accuracy"

def evaluate():
    # Local variable
    score = 0.95
    print(f"{metric_name} score is {score}")

evaluate()
print(metric_name)
#print(score)
# Out:
# Inside function: Accuracy score is 0.95
# Accuracy
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 11
#       7     print(f"Inside function: {metric_name} score is {score}")
#       8
#       9 evaluate()
#      10 print(metric_name)
# ---> 11 print(score)
#
# NameError: name 'score' is not defined

# %% [markdown]
# ### The `global` Keyword
# If you try to change a global variable inside a function, Python will normally create a new local variable with the same name. To modify the actual global variable, you must declare it using the **`global`** keyword.

# %%
a=10 #global variable 

def change():
    global a
    a=20        #copy of global variable
    print("after changing the 'a' variable :",a)

change()
print("original : ",a)
# Out:
# after changing the 'a' variable : 20
# original :  20

# %%
epoch_counter = 5 # Global variable

def run_epoch():
    global epoch_counter
    epoch_counter += 1 # Increments the global variable
    print(f"Inside run_epoch: epoch_counter incremented to {epoch_counter}")

print(f"Before: epoch_counter = {epoch_counter}")
run_epoch()
print(f"After: epoch_counter = {epoch_counter}")

# %% [markdown]
# ## 6. Recursive Functions
#
# A **recursive function** is a function that calls itself to solve a problem. It works by breaking a complex problem down into smaller, simpler steps of the same problem.
#
# Every recursive function must have two crucial parts:
# 1. **Base Case**: A simple condition that stops the recursion (prevents infinite loops!).
# 2. **Recursive Case**: The section where the function calls itself with a slightly simpler input.
#
# ### 6.1 Simple Example: Factorial
# The factorial of a number $n$ (written as $n!$) is the product of all positive integers less than or equal to $n$.
# For example: $5! = 5 \times 4 \times 3 \times 2 \times 1 = 120$.
# Formula: $n! = n \times (n-1)!$ with base case $0! = 1$ and $1! = 1$.

# %%
# Recursive function to calculate factorial
def calculate_factorial(n):
    if n == 0 or n == 1:
        return 1
    else:
        return n * calculate_factorial(n - 1)
print(calculate_factorial(5))
# Out:
# 120

# %% [markdown]
# ### Exercise 3: Recursive Fibonacci Sequence
# The Fibonacci sequence is a series of numbers where each number is the sum of the two preceding ones: `0, 1, 1, 2, 3, 5, 8, 13, 21, ...`
#
# Formula:
# - `fib(0) = 0` (Base Case 1)
# - `fib(1) = 1` (Base Case 2)
# - `fib(n) = fib(n-1) + fib(n-2)` (Recursive Case)
#
# Write a recursive function named `fibonacci(n)` that returns the n-th Fibonacci number. Call it with argument `6` and verify it prints `8`.
#
# *(Write your code in the cell below)*

# %%
# Exercise 3: Write your code here
def fibonacci(n):
    if n == 0 or n==1:
        return n
    else:
        return fibonacci(n - 1) + fibonacci(n - 2)
print(fibonacci(6))

# Testing
print(f"Fibonacci(6) = {fibonacci(6)}")
# Out:
# Fibonacci(6) = 8
